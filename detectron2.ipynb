# %% [markdown]
# ## **Распознавание объектов на изображениях с использованием сверточных нейронных сетей (CNN)**
# ## Автор: Евтых Ратмир
# ## Дата: 2025-03-30

# %%
'''
Компилятор может пожаловаться,
что такая библиотека уже есть и предложить перезапуск,
в таком случае отказываемся от перезапуска
'''
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-e8xi4ur1
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-e8xi4ur1
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 9604f5995cc628619f0e4fd913453b4d7d61db3f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.10.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.0.1)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.1.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (4.67.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.18.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (25.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (4.3.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (3.0.2)

# %%
# !pip install pyyaml
# !pip install pycocotools
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (6.0.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pycocotools) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.17.0)

# %%
import os
import cv2
import torch
import json
from collections import defaultdict, Counter
from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.data import MetadataCatalog, build_detection_test_loader
from detectron2.data.datasets import register_coco_instances
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import Visualizer


def setup_model():
    # Создаем конфигурацию для модели Mask R-CNN с Feature Pyramid Network (FPN)
    cfg = get_cfg()

    # Загружаем конфигурацию из model zoo Detectron2 для instance segmentation
    cfg.merge_from_file(model_zoo.get_config_file
     (
        "COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
        )
     )

    # Устанавливаем порог уверенности для отображения предсказаний
    cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5

    # Загружаем предобученные веса для данной модели
    cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(
        "COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
        )

    # Создаем предиктор
    predictor = DefaultPredictor(cfg)

    # Получаем метаданные для отображения имен классов
    metadata = MetadataCatalog.get(cfg.DATASETS.TRAIN[0])

    return predictor, metadata, cfg


def detect_objects(
    image_path,
    output_path,
    predictor,
    metadata,
    ):
    # Загружаем изображение
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(
            f"Не удалось загрузить изображение по пути: {image_path}"
            )

    outputs = predictor(image)
    instances = outputs["instances"]

    # Визуализируем результаты
    v = Visualizer(image[:, :, ::-1], metadata=metadata, scale=1.2)
    out = v.draw_instance_predictions(instances.to("cpu"))
    result_image = out.get_image()[:, :, ::-1]

    # Сохраняем изображение с нарисованными сегментациями
    cv2.imwrite(output_path, result_image)
    print(f"Результат сохранён в {output_path}")

    # Подсчет обьектов
    if instances.has("pred_classes"):
      pred_classes = instances.pred_classes.cpu().numpy()
      counts = Counter(pred_classes)

      # Сопоставляем числовые метки с именами классов через metadata
      class_names = metadata.get("thing_classes", None)
      if class_names:
          print("Обнаруженные объекты:")
          for cls_id, cnt in counts.items():
              print(f"{class_names[int(cls_id)]}: {cnt}")
      else:
          print("Обнаруженные классы (числовые метки):", counts)
    else:
        print("Объекты не обнаружены.")

def test_on_coco(cfg, predictor):
    register_coco_instances(
        "my_coco_val", {},
        "drive/MyDrive/annotations/instances_val2017.json",
        "drive/MyDrive/val2017/"
    )

    # Создаем COCOEvaluator для набора данных валидации COCO 2017
    evaluator = COCOEvaluator(
        "my_coco_val", cfg, False,
        output_dir="drive/MyDrive/coco_eval"
    )
    val_loader = build_detection_test_loader(cfg, "my_coco_val")
    # Выполняем инференс по всему набору данных и вычисляем метрики
    metrics = inference_on_dataset(predictor.model, val_loader, evaluator)
    print("Метрики на COCO 2017 val:")
    print(metrics)

def process_coco_results(json_path):
    # Загружаем данные из JSON-файла
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Группируем результаты по image_id и category_id, сохраняем список score
    summary = defaultdict(lambda: defaultdict(list))
    for det in data:
        image_id = det["image_id"]
        category_id = det["category_id"]
        score = det["score"]
        summary[image_id][category_id].append(score)
    return summary

def print_summary(summary, category_names=None):
    print("Сводная информация по изображениям:")
    # Словарь для общей агрегации: ключ – cat_id, значение – список всех score по всем изображениям
    overall = {}

    for image_id, cats in summary.items():
        print(f"Image {image_id}:")
        for cat_id, scores in cats.items():
            count = len(scores)
            avg_score = sum(scores) / count if count > 0 else 0
            # Добавляем данные в общий словарь
            if cat_id not in overall:
                overall[cat_id] = []
            overall[cat_id].extend(scores)
            # Если есть сопоставление с именами категорий, выводим имя
            if category_names and cat_id in category_names:
                cat_name = category_names[cat_id]
            else:
                cat_name = f"Category {cat_id}"
            print(f"  {cat_name}: {count} обнаружений, средний score = {avg_score:.3f}")
        print()

    # Вывод общей информации по всем изображениям
    print("Общая сводная информация по всем изображениям:")
    for cat_id, scores in overall.items():
        total_count = len(scores)
        overall_avg = sum(scores) / total_count if total_count > 0 else 0
        if category_names and cat_id in category_names:
            cat_name = category_names[cat_id]
        else:
            cat_name = f"Category {cat_id}"
        print(f"  Модель справилась с угадыванием {cat_name}: {total_count} обнаружений, средний score = {overall_avg:.3f}")

def main():
    # predictor, metadata, cfg = setup_model()
    # detect_objects(image_path, output_path, predictor, metadata)

    # test_on_coco(cfg, predictor)
    coco_category_names = {
      0: "__фон__",
      1: "человек",
      2: "велосипед",
      3: "автомобиль",
      4: "мотоцикл",
      5: "самолет",
      6: "автобус",
      7: "поезд",
      8: "грузовик",
      9: "лодка",
      10: "светофор",
      11: "пожарный гидрант",
      12: "дорожный знак",
      13: "знак остановки",
      14: "паркомат",
      15: "скамейка",
      16: "птица",
      17: "кошка",
      18: "собака",
      19: "лошадь",
      20: "овца",
      21: "корова",
      22: "слон",
      23: "медведь",
      24: "зебра",
      25: "жираф",
      26: "шляпа",
      27: "рюкзак",
      28: "зонт",
      29: "обувь",
      30: "очки",
      31: "сумка",
      32: "галстук",
      33: "чемодан",
      34: "фрисби",
      35: "лыжи",
      36: "сноуборд",
      37: "спортивный мяч",
      38: "воздушный змей",
      39: "бейсбольная бита",
      40: "бейсбольная перчатка",
      41: "скейтборд",
      42: "доска для серфинга",
      43: "теннисная ракетка",
      44: "бутылка",
      45: "тарелка",
      46: "бокал",
      47: "чашка",
      48: "вилка",
      49: "нож",
      50: "ложка",
      51: "миска",
      52: "банан",
      53: "яблоко",
      54: "сэндвич",
      55: "апельсин",
      56: "брокколи",
      57: "морковь",
      58: "хот-дог",
      59: "пицца",
      60: "пончик",
      61: "торт",
      62: "стул",
      63: "диван",
      64: "растение в горшке",
      65: "кровать",
      66: "зеркало",
      67: "обеденный стол",
      68: "окно",
      69: "письменный стол",
      70: "унитаз",
      71: "дверь",
      72: "телевизор",
      73: "ноутбук",
      74: "мышь (компьютерная)",
      75: "пульт",
      76: "клавиатура",
      77: "мобильный телефон",
      78: "микроволновка",
      79: "духовка",
      80: "тостер",
      81: "раковина",
      82: "холодильник",
      83: "блендер",
      84: "книга",
      85: "часы",
      86: "ваза",
      87: "ножницы",
      88: "плюшевый мишка",
      89: "фен",
      90: "зубная щетка",
      91: "расческа"
    }

    summary = process_coco_results("drive/MyDrive/coco_eval/coco_instances_results.json")
    print_summary(summary, category_names=coco_category_names)

if __name__ == "__main__":
    main()
# Out:
# Сводная информация по изображениям:
# Image 139:
#   человек: 2 обнаружений, средний score = 0.882
#   стул: 4 обнаружений, средний score = 0.842
#   телевизор: 2 обнаружений, средний score = 0.957
#   ваза: 5 обнаружений, средний score = 0.714
#   холодильник: 3 обнаружений, средний score = 0.830
#   растение в горшке: 1 обнаружений, средний score = 0.833
#   обеденный стол: 2 обнаружений, средний score = 0.659
#   часы: 1 обнаружений, средний score = 0.713
#   бутылка: 1 обнаружений, средний score = 0.664
#
# Image 285:
#   медведь: 1 обнаружений, средний score = 0.987
#
# Image 632:
#   растение в горшке: 2 обнаружений, средний score = 0.992
#   стул: 1 обнаружений, средний score = 0.993
#   кровать: 1 обнаружений, средний score = 0.990
#   бутылка: 1 обнаружений, средний score = 0.969
#   книга: 20 обнаружений, средний score = 0.577
#
# Image 724:
#   знак остановки: 2 обнаружений, средний score = 0.841
#   грузовик: 1 обнаружений, средний score = 0.931
#   автомобиль: 1 обнаружений, средний score = 0.549
#
# Image 776:
#   плюшевый мишка: 4 обнаружений, средний score = 0.822
#
# Image 785:
#   человек: 1 обнаружений, средний score = 0.999
#   лыжи: 1 обнаружений, средний score = 0.911
#
# Image 802:
#   духовка: 1 обнаружений, средний score = 0.996
#   холодильник: 1 обнаружений, средний score = 0.994
#
# Image 872:
#   человек: 2 обнаружений, средний score = 0.991
#   спортивный мяч: 2 обнаружений, средний score = 0.817
#
# Image 885:
#   человек: 12 обнаружений, средний score = 0.856
#   теннисная ракетка: 1 обнаружений, средний score = 0.998
#   бейсбольная бита: 1 обнаружений, средний score = 0.559
#
# Image 1000:
#   человек: 13 обнаружений, средний score = 0.901
#   теннисная ракетка: 1 обнаружений, средний score = 0.880
#   сумка: 2 обнаружений, средний score = 0.742
#
# Image 1268:
#   человек: 4 обнаружений, средний score = 0.992
#   сумка: 3 обнаружений, средний score = 0.921
#   птица: 1 обнаружений, средний score = 0.995
#   лодка: 3 обнаружений, средний score = 0.670
#   рюкзак: 1 обнаружений, средний score = 0.818
#
# Image 1296:
#   человек: 5 обнаружений, средний score = 0.704
#   мобильный телефон: 3 обнаружений, средний score = 0.767
#
# Image 1353:
#   человек: 6 обнаружений, средний score = 0.853
#
# Image 1425:
#   торт: 1 обнаружений, средний score = 0.882
#   миска: 2 обнаружений, средний score = 0.645
#   человек: 1 обнаружений, средний score = 0.744
#   обеденный стол: 1 обнаружений, средний score = 0.654
#   пончик: 1 обнаружений, средний score = 0.537
#
# Image 1490:
#   человек: 1 обнаружений, средний score = 0.999
#   доска для серфинга: 1 обнаружений, средний score = 0.934
#
# Image 1503:
#   ноутбук: 1 обнаружений, средний score = 0.999
#   клавиатура: 1 обнаружений, средний score = 0.995
#   телевизор: 1 обнаружений, средний score = 0.991
#   мышь (компьютерная): 1 обнаружений, средний score = 0.989
#
# Image 1532:
#   автомобиль: 8 обнаружений, средний score = 0.812
#   грузовик: 2 обнаружений, средний score = 0.942
#   человек: 1 обнаружений, средний score = 0.628
#
# Image 1584:
#   автобус: 3 обнаружений, средний score = 0.938
#   человек: 7 обнаружений, средний score = 0.852
#   грузовик: 1 обнаружений, средний score = 0.637
#   автомобиль: 1 обнаружений, средний score = 0.562
#
# Image 1675:
#   кошка: 2 обнаружений, средний score = 0.791
#   клавиатура: 1 обнаружений, средний score = 0.772
#   ноутбук: 1 обнаружений, средний score = 0.614
#
# Image 1761:
#   самолет: 2 обнаружений, средний score = 0.999
#   лодка: 1 обнаружений, средний score = 0.547
#
# Image 1818:
#   зебра: 2 обнаружений, средний score = 0.931
#
# Image 1993:
#   стул: 1 обнаружений, средний score = 0.995
#   кровать: 1 обнаружений, средний score = 0.994
#   обеденный стол: 1 обнаружений, средний score = 0.987
#   чашка: 1 обнаружений, средний score = 0.502
#
# Image 2006:
#   автобус: 1 обнаружений, средний score = 1.000
#   человек: 3 обнаружений, средний score = 0.978
#   светофор: 1 обнаружений, средний score = 0.763
#
# Image 2149:
#   яблоко: 5 обнаружений, средний score = 0.823
#
# Image 2153:
#   человек: 5 обнаружений, средний score = 0.942
#   бейсбольная бита: 1 обнаружений, средний score = 0.969
#   бейсбольная перчатка: 1 обнаружений, средний score = 0.538
#
# Image 2157:
#   бокал: 9 обнаружений, средний score = 0.849
#   торт: 1 обнаружений, средний score = 0.967
#   обеденный стол: 1 обнаружений, средний score = 0.957
#   морковь: 1 обнаружений, средний score = 0.914
#   чашка: 2 обнаружений, средний score = 0.637
#   нож: 2 обнаружений, средний score = 0.656
#   бутылка: 1 обнаружений, средний score = 0.655
#   сэндвич: 2 обнаружений, средний score = 0.572
#   миска: 3 обнаружений, средний score = 0.548
#
# Image 2261:
#   человек: 1 обнаружений, средний score = 0.999
#   доска для серфинга: 1 обнаружений, средний score = 0.953
#
# Image 2299:
#   человек: 38 обнаружений, средний score = 0.860
#   галстук: 10 обнаружений, средний score = 0.766
#   бейсбольная перчатка: 1 обнаружений, средний score = 0.703
#
# Image 2431:
#   бокал: 1 обнаружений, средний score = 0.998
#   человек: 2 обнаружений, средний score = 0.801
#   обеденный стол: 2 обнаружений, средний score = 0.837
#   ложка: 1 обнаружений, средний score = 0.910
#   миска: 1 обнаружений, средний score = 0.908
#   чашка: 1 обнаружений, средний score = 0.820
#   нож: 2 обнаружений, средний score = 0.700
#   стул: 2 обнаружений, средний score = 0.579
#
# Image 2473:
#   человек: 5 обнаружений, средний score = 0.905
#   лыжи: 1 обнаружений, средний score = 0.946
#
# Image 2532:
#   человек: 1 обнаружений, средний score = 0.999
#   лыжи: 1 обнаружений, средний score = 0.967
#
# Image 2587:
#   банан: 1 обнаружений, средний score = 0.853
#
# Image 2592:
#   чашка: 1 обнаружений, средний score = 0.999
#   нож: 2 обнаружений, средний score = 0.806
#   обеденный стол: 1 обнаружений, средний score = 0.765
#
# Image 2685:
#   человек: 8 обнаружений, средний score = 0.826
#   чашка: 1 обнаружений, средний score = 0.805
#   мобильный телефон: 1 обнаружений, средний score = 0.750
#   бутылка: 2 обнаружений, средний score = 0.623
#   нож: 1 обнаружений, средний score = 0.548
#
# Image 2923:
#   птица: 2 обнаружений, средний score = 0.976
#   воздушный змей: 1 обнаружений, средний score = 0.910
#   человек: 1 обнаружений, средний score = 0.892
#   лодка: 1 обнаружений, средний score = 0.521
#
# Image 3156:
#   человек: 1 обнаружений, средний score = 0.998
#   унитаз: 2 обнаружений, средний score = 0.876
#
# Image 3255:
#   человек: 6 обнаружений, средний score = 0.863
#
# Image 3501:
#   брокколи: 2 обнаружений, средний score = 0.975
#   обеденный стол: 1 обнаружений, средний score = 0.584
#
# Image 3553:
#   скейтборд: 2 обнаружений, средний score = 0.944
#   человек: 2 обнаружений, средний score = 0.939
#   скамейка: 2 обнаружений, средний score = 0.613
#   доска для серфинга: 1 обнаружений, средний score = 0.573
#
# Image 3661:
#   банан: 4 обнаружений, средний score = 0.815
#   чашка: 1 обнаружений, средний score = 0.665
#   обеденный стол: 1 обнаружений, средний score = 0.523
#
# Image 3845:
#   чашка: 1 обнаружений, средний score = 0.996
#   брокколи: 3 обнаружений, средний score = 0.914
#   морковь: 4 обнаружений, средний score = 0.883
#   обеденный стол: 1 обнаружений, средний score = 0.955
#   стул: 1 обнаружений, средний score = 0.921
#   нож: 1 обнаружений, средний score = 0.733
#
# Image 3934:
#   человек: 7 обнаружений, средний score = 0.893
#   диван: 1 обнаружений, средний score = 0.984
#   бокал: 1 обнаружений, средний score = 0.961
#   пульт: 2 обнаружений, средний score = 0.709
#   чашка: 1 обнаружений, средний score = 0.812
#
# Image 4134:
#   человек: 14 обнаружений, средний score = 0.930
#   галстук: 1 обнаружений, средний score = 0.988
#   бокал: 3 обнаружений, средний score = 0.855
#   ноутбук: 1 обнаружений, средний score = 0.876
#   обеденный стол: 5 обнаружений, средний score = 0.717
#   стул: 2 обнаружений, средний score = 0.610
#   чашка: 1 обнаружений, средний score = 0.511
#
# Image 4395:
#   человек: 1 обнаружений, средний score = 1.000
#   галстук: 1 обнаружений, средний score = 0.999
#
# Image 4495:
#   телевизор: 1 обнаружений, средний score = 0.991
#   стул: 1 обнаружений, средний score = 0.978
#   диван: 1 обнаружений, средний score = 0.965
#
# Image 4765:
#   человек: 1 обнаружений, средний score = 1.000
#   доска для серфинга: 3 обнаружений, средний score = 0.656
#
# Image 4795:
#   ноутбук: 3 обнаружений, средний score = 0.790
#   кошка: 1 обнаружений, средний score = 0.989
#   мобильный телефон: 1 обнаружений, средний score = 0.923
#   телевизор: 1 обнаружений, средний score = 0.698
#   стул: 2 обнаружений, средний score = 0.659
#
# Image 5001:
#   человек: 22 обнаружений, средний score = 0.840
#   галстук: 1 обнаружений, средний score = 0.584
#
# Image 5037:
#   автобус: 1 обнаружений, средний score = 0.999
#   человек: 7 обнаружений, средний score = 0.849
#   автомобиль: 2 обнаружений, средний score = 0.772
#
# Image 5060:
#   человек: 1 обнаружений, средний score = 0.997
#   мобильный телефон: 1 обнаружений, средний score = 0.916
#   стул: 1 обнаружений, средний score = 0.520
#
# Image 5193:
#   человек: 7 обнаружений, средний score = 0.922
#   мобильный телефон: 1 обнаружений, средний score = 0.988
#   бутылка: 1 обнаружений, средний score = 0.981
#   доска для серфинга: 1 обнаружений, средний score = 0.811
#   воздушный змей: 1 обнаружений, средний score = 0.684
#   обеденный стол: 1 обнаружений, средний score = 0.548
#   стул: 1 обнаружений, средний score = 0.523
#
# Image 5477:
#   самолет: 2 обнаружений, средний score = 0.910
#
# Image 5503:
#   унитаз: 3 обнаружений, средний score = 0.749
#   человек: 1 обнаружений, средний score = 0.797
#
# Image 5529:
#   человек: 1 обнаружений, средний score = 1.000
#   лыжи: 1 обнаружений, средний score = 0.889
#
# Image 5586:
#   человек: 9 обнаружений, средний score = 0.781
#   теннисная ракетка: 1 обнаружений, средний score = 0.945
#
# Image 5600:
#   миска: 2 обнаружений, средний score = 0.975
#   бокал: 2 обнаружений, средний score = 0.693
#   обеденный стол: 2 обнаружений, средний score = 0.593
#   апельсин: 2 обнаружений, средний score = 0.621
#
# Image 5992:
#   овца: 5 обнаружений, средний score = 0.994
#
# Image 6012:
#   банан: 5 обнаружений, средний score = 0.912
#   яблоко: 1 обнаружений, средний score = 0.942
#   обеденный стол: 1 обнаружений, средний score = 0.568
#
# Image 6040:
#   поезд: 1 обнаружений, средний score = 0.982
#   человек: 7 обнаружений, средний score = 0.820
#   грузовик: 2 обнаружений, средний score = 0.820
#   автомобиль: 1 обнаружений, средний score = 0.906
#   автобус: 1 обнаружений, средний score = 0.840
#   светофор: 1 обнаружений, средний score = 0.757
#
# Image 6213:
#   раковина: 2 обнаружений, средний score = 0.819
#
# Image 6460:
#   человек: 1 обнаружений, средний score = 0.975
#   доска для серфинга: 1 обнаружений, средний score = 0.862
#
# Image 6471:
#   человек: 12 обнаружений, средний score = 0.909
#   бейсбольная перчатка: 1 обнаружений, средний score = 0.995
#   бейсбольная бита: 1 обнаружений, средний score = 0.986
#   бутылка: 2 обнаружений, средний score = 0.899
#
# Image 6614:
#   плюшевый мишка: 1 обнаружений, средний score = 0.724
#   пончик: 4 обнаружений, средний score = 0.613
#   яблоко: 1 обнаружений, средний score = 0.646
#
# Image 6723:
#   автомобиль: 4 обнаружений, средний score = 0.962
#   автобус: 1 обнаружений, средний score = 0.783
#   человек: 2 обнаружений, средний score = 0.736
#
# Image 6763:
#   человек: 3 обнаружений, средний score = 0.953
#   телевизор: 1 обнаружений, средний score = 0.976
#   галстук: 1 обнаружений, средний score = 0.512
#
# Image 6771:
#   человек: 10 обнаружений, средний score = 0.871
#   сумка: 1 обнаружений, средний score = 0.716
#   мобильный телефон: 1 обнаружений, средний score = 0.617
#
# Image 6818:
#   унитаз: 1 обнаружений, средний score = 0.906
#
# Image 6894:
#   человек: 1 обнаружений, средний score = 0.995
#   слон: 4 обнаружений, средний score = 0.786
#
# Image 6954:
#   человек: 5 обнаружений, средний score = 0.998
#   фрисби: 2 обнаружений, средний score = 0.984
#   спортивный мяч: 1 обнаружений, средний score = 0.526
#
# Image 7088:
#   человек: 1 обнаружений, средний score = 0.999
#   зонт: 1 обнаружений, средний score = 0.991
#   автомобиль: 1 обнаружений, средний score = 0.796
#
# Image 7108:
#   слон: 3 обнаружений, средний score = 0.885
#   человек: 1 обнаружений, средний score = 0.954
#   корова: 1 обнаружений, средний score = 0.848
#
# Image 7278:
#   человек: 1 обнаружений, средний score = 0.997
#   доска для серфинга: 1 обнаружений, средний score = 0.902
#
# Image 7281:
#   человек: 9 обнаружений, средний score = 0.908
#   лошадь: 2 обнаружений, средний score = 0.996
#
# Image 7386:
#   собака: 1 обнаружений, средний score = 0.897
#   велосипед: 2 обнаружений, средний score = 0.758
#   мотоцикл: 1 обнаружений, средний score = 0.638
#
# Image 7511:
#   человек: 9 обнаружений, средний score = 0.797
#   воздушный змей: 1 обнаружений, средний score = 0.997
#   рюкзак: 1 обнаружений, средний score = 0.586
#
# Image 7574:
#   холодильник: 1 обнаружений, средний score = 0.992
#   бутылка: 3 обнаружений, средний score = 0.963
#   микроволновка: 1 обнаружений, средний score = 0.930
#   ваза: 2 обнаружений, средний score = 0.832
#   миска: 4 обнаружений, средний score = 0.700
#   раковина: 3 обнаружений, средний score = 0.773
#   духовка: 1 обнаружений, средний score = 0.672
#   чашка: 2 обнаружений, средний score = 0.552
#
# Image 7784:
#   воздушный змей: 1 обнаружений, средний score = 0.990
#
# Image 7795:
#   кровать: 4 обнаружений, средний score = 0.917
#   часы: 1 обнаружений, средний score = 0.547
#
# Image 7816:
#   человек: 9 обнаружений, средний score = 0.965
#   мотоцикл: 1 обнаружений, средний score = 0.995
#
# Image 7818:
#   ваза: 2 обнаружений, средний score = 0.786
#   бокал: 3 обнаружений, средний score = 0.775
#   стул: 1 обнаружений, средний score = 0.844
#   обеденный стол: 1 обнаружений, средний score = 0.828
#   нож: 1 обнаружений, средний score = 0.729
#   вилка: 1 обнаружений, средний score = 0.547
#   растение в горшке: 1 обнаружений, средний score = 0.507
#
# Image 7888:
#   часы: 2 обнаружений, средний score = 0.988
#
# Image 7977:
#   человек: 2 обнаружений, средний score = 0.922
#   скейтборд: 1 обнаружений, средний score = 0.997
#   автомобиль: 1 обнаружений, средний score = 0.831
#
# Image 7991:
#   нож: 1 обнаружений, средний score = 0.938
#   морковь: 10 обнаружений, средний score = 0.580
#   чашка: 1 обнаружений, средний score = 0.809
#   миска: 1 обнаружений, средний score = 0.750
#   ложка: 1 обнаружений, средний score = 0.702
#
# Image 8021:
#   человек: 3 обнаружений, средний score = 0.965
#   галстук: 1 обнаружений, средний score = 0.986
#
# Image 8211:
#   человек: 3 обнаружений, средний score = 0.836
#   мотоцикл: 2 обнаружений, средний score = 0.997
#   стул: 1 обнаружений, средний score = 0.865
#   растение в горшке: 1 обнаружений, средний score = 0.814
#
# Image 8277:
#   миска: 1 обнаружений, средний score = 0.981
#   вилка: 2 обнаружений, средний score = 0.931
#   брокколи: 2 обнаружений, средний score = 0.624
#
# Image 8532:
#   человек: 1 обнаружений, средний score = 0.999
#   галстук: 1 обнаружений, средний score = 0.997
#
# Image 8629:
#   пицца: 5 обнаружений, средний score = 0.834
#   вилка: 1 обнаружений, средний score = 0.935
#
# Image 8690:
#   человек: 5 обнаружений, средний score = 0.824
#   корова: 2 обнаружений, средний score = 0.630
#   собака: 2 обнаружений, средний score = 0.554
#   растение в горшке: 1 обнаружений, средний score = 0.558
#
# Image 8762:
#   светофор: 6 обнаружений, средний score = 0.900
#   автомобиль: 1 обнаружений, средний score = 0.965
#
# Image 8844:
#   человек: 2 обнаружений, средний score = 0.982
#   банан: 2 обнаружений, средний score = 0.876
#
# Image 8899:
#   пожарный гидрант: 1 обнаружений, средний score = 0.997
#   велосипед: 1 обнаружений, средний score = 0.901
#
# Image 9378:
#   человек: 10 обнаружений, средний score = 0.769
#   фрисби: 1 обнаружений, средний score = 0.909
#
# Image 9400:
#   человек: 11 обнаружений, средний score = 0.840
#   ноутбук: 6 обнаружений, средний score = 0.813
#   чашка: 2 обнаружений, средний score = 0.937
#   мышь (компьютерная): 1 обнаружений, средний score = 0.972
#   клавиатура: 2 обнаружений, средний score = 0.757
#   бутылка: 1 обнаружений, средний score = 0.681
#
# Image 9448:
#   человек: 1 обнаружений, средний score = 1.000
#   зонт: 1 обнаружений, средний score = 0.985
#   бутылка: 1 обнаружений, средний score = 0.854
#
# Image 9483:
#   человек: 2 обнаружений, средний score = 0.995
#   клавиатура: 1 обнаружений, средний score = 0.995
#   телевизор: 1 обнаружений, средний score = 0.981
#   мышь (компьютерная): 1 обнаружений, средний score = 0.968
#   ноутбук: 1 обнаружений, средний score = 0.945
#   галстук: 1 обнаружений, средний score = 0.940
#   стул: 4 обнаружений, средний score = 0.705
#
# Image 9590:
#   человек: 5 обнаружений, средний score = 0.969
#   чашка: 8 обнаружений, средний score = 0.724
#   миска: 8 обнаружений, средний score = 0.669
#   бутылка: 2 обнаружений, средний score = 0.947
#   часы: 1 обнаружений, средний score = 0.950
#   обеденный стол: 1 обнаружений, средний score = 0.786
#
# Image 9769:
#   человек: 1 обнаружений, средний score = 0.992
#   грузовик: 1 обнаружений, средний score = 0.964
#   пожарный гидрант: 1 обнаружений, средний score = 0.699
#   лодка: 1 обнаружений, средний score = 0.576
#
# Image 9772:
#   телевизор: 1 обнаружений, средний score = 0.993
#   человек: 1 обнаружений, средний score = 0.988
#   раковина: 3 обнаружений, средний score = 0.864
#   бутылка: 2 обнаружений, средний score = 0.638
#   диван: 1 обнаружений, средний score = 0.572
#
# Image 9891:
#   человек: 3 обнаружений, средний score = 0.878
#   автомобиль: 4 обнаружений, средний score = 0.695
#   чемодан: 2 обнаружений, средний score = 0.852
#   рюкзак: 2 обнаружений, средний score = 0.711
#
# Image 9914:
#   нож: 1 обнаружений, средний score = 0.959
#   миска: 2 обнаружений, средний score = 0.922
#   торт: 1 обнаружений, средний score = 0.728
#   обеденный стол: 1 обнаружений, средний score = 0.702
#   сэндвич: 1 обнаружений, средний score = 0.562
#
# Image 10092:
#   кровать: 1 обнаружений, средний score = 0.994
#   обеденный стол: 2 обнаружений, средний score = 0.811
#   стул: 4 обнаружений, средний score = 0.688
#
# Image 10363:
#   кошка: 1 обнаружений, средний score = 0.999
#   бутылка: 4 обнаружений, средний score = 0.748
#   велосипед: 2 обнаружений, средний score = 0.854
#   автомобиль: 2 обнаружений, средний score = 0.574
#
# Image 10583:
#   чашка: 1 обнаружений, средний score = 0.892
#   обеденный стол: 1 обнаружений, средний score = 0.874
#   нож: 1 обнаружений, средний score = 0.870
#   сэндвич: 1 обнаружений, средний score = 0.703
#
# Image 10707:
#   человек: 3 обнаружений, средний score = 0.996
#   ноутбук: 1 обнаружений, средний score = 0.992
#   диван: 3 обнаружений, средний score = 0.810
#   бутылка: 2 обнаружений, средний score = 0.738
#   обеденный стол: 1 обнаружений, средний score = 0.884
#   чашка: 2 обнаружений, средний score = 0.771
#   пульт: 2 обнаружений, средний score = 0.605
#
# Image 10764:
#   человек: 1 обнаружений, средний score = 0.999
#   бейсбольная перчатка: 1 обнаружений, средний score = 0.994
#
# Image 10977:
#   унитаз: 1 обнаружений, средний score = 0.973
#   бутылка: 2 обнаружений, средний score = 0.883
#   раковина: 2 обнаружений, средний score = 0.690
#
# Image 10995:
#   кровать: 1 обнаружений, средний score = 0.995
#
# Image 11051:
#   человек: 2 обнаружений, средний score = 0.999
#   галстук: 1 обнаружений, средний score = 0.986
#
# Image 11122:
#   знак остановки: 1 обнаружений, средний score = 0.998
#   автомобиль: 1 обнаружений, средний score = 0.708
#
# Image 11149:
#   человек: 3 обнаружений, средний score = 0.836
#   велосипед: 3 обнаружений, средний score = 0.831
#   мотоцикл: 1 обнаружений, средний score = 0.987
#
# Image 11197:
#   человек: 4 обнаружений, средний score = 0.981
#   велосипед: 1 обнаружений, средний score = 0.995
#   светофор: 6 обнаружений, средний score = 0.824
#   автомобиль: 4 обнаружений, средний score = 0.941
#   стул: 1 обнаружений, средний score = 0.821
#   пожарный гидрант: 1 обнаружений, средний score = 0.744
#   рюкзак: 2 обнаружений, средний score = 0.593
#   фрисби: 1 обнаружений, средний score = 0.598
#   сумка: 1 обнаружений, средний score = 0.552
#
# Image 11511:
#   человек: 5 обнаружений, средний score = 0.969
#   мотоцикл: 1 обнаружений, средний score = 0.828
#   сумка: 1 обнаружений, средний score = 0.799
#
# Image 11615:
#   знак остановки: 2 обнаружений, средний score = 0.853
#
# Image 11699:
#   человек: 3 обнаружений, средний score = 0.978
#   чемодан: 1 обнаружений, средний score = 0.984
#   сумка: 4 обнаружений, средний score = 0.808
#
# Image 11760:
#   зебра: 3 обнаружений, средний score = 0.998
#
# Image 11813:
#   светофор: 1 обнаружений, средний score = 0.873
#   стул: 3 обнаружений, средний score = 0.675
#   раковина: 3 обнаружений, средний score = 0.655
#   ноутбук: 1 обнаружений, средний score = 0.671
#   телевизор: 1 обнаружений, средний score = 0.528
#
# Image 12062:
#   овца: 2 обнаружений, средний score = 0.786
#   автомобиль: 1 обнаружений, средний score = 0.679
#
# Image 12120:
#   человек: 13 обнаружений, средний score = 0.828
#   спортивный мяч: 1 обнаружений, средний score = 0.987
#   теннисная ракетка: 2 обнаружений, средний score = 0.926
#   стул: 1 обнаружений, средний score = 0.563
#
# Image 12280:
#   человек: 1 обнаружений, средний score = 0.997
#   сумка: 2 обнаружений, средний score = 0.676
#   чемодан: 1 обнаружений, средний score = 0.739
#
# Image 12576:
#   чашка: 5 обнаружений, средний score = 0.912
#   телевизор: 1 обнаружений, средний score = 0.988
#   пицца: 3 обнаружений, средний score = 0.969
#   человек: 1 обнаружений, средний score = 0.948
#   обеденный стол: 1 обнаружений, средний score = 0.934
#   нож: 3 обнаружений, средний score = 0.647
#   вилка: 1 обнаружений, средний score = 0.769
#   стул: 1 обнаружений, средний score = 0.521
#
# Image 12639:
#   человек: 19 обнаружений, средний score = 0.835
#   бейсбольная перчатка: 1 обнаружений, средний score = 0.988
#   бейсбольная бита: 2 обнаружений, средний score = 0.796
#   стул: 2 обнаружений, средний score = 0.601
#
# Image 12667:
#   банан: 1 обнаружений, средний score = 0.995
#   микроволновка: 1 обнаружений, средний score = 0.805
#   пульт: 1 обнаружений, средний score = 0.759
#
# Image 12670:
#   человек: 37 обнаружений, средний score = 0.818
#   плюшевый мишка: 1 обнаружений, средний score = 0.952
#   рюкзак: 1 обнаружений, средний score = 0.725
#   сумка: 1 обнаружений, средний score = 0.693
#
# Image 12748:
#   человек: 2 обнаружений, средний score = 0.899
#   лошадь: 1 обнаружений, средний score = 0.996
#
# Image 13004:
#   обеденный стол: 1 обнаружений, средний score = 0.868
#   пончик: 1 обнаружений, средний score = 0.587
#
# Image 13177:
#   человек: 1 обнаружений, средний score = 0.999
#   мотоцикл: 1 обнаружений, средний score = 0.951
#   велосипед: 2 обнаружений, средний score = 0.896
#   нож: 1 обнаружений, средний score = 0.612
#   обеденный стол: 1 обнаружений, средний score = 0.567
#
# Image 13201:
#   скейтборд: 1 обнаружений, средний score = 0.999
#   человек: 1 обнаружений, средний score = 0.998
#
# Image 13291:
#   человек: 6 обнаружений, средний score = 0.884
#   фрисби: 4 обнаружений, средний score = 0.990
#
# Image 13348:
#   самолет: 2 обнаружений, средний score = 0.965
#   человек: 3 обнаружений, средний score = 0.956
#   грузовик: 5 обнаружений, средний score = 0.621
#
# Image 13546:
#   человек: 2 обнаружений, средний score = 0.993
#   скамейка: 4 обнаружений, средний score = 0.828
#   скейтборд: 1 обнаружений, средний score = 0.980
#   автомобиль: 1 обнаружений, средний score = 0.710
#
# Image 13597:
#   торт: 1 обнаружений, средний score = 0.969
#
# Image 13659:
#   человек: 5 обнаружений, средний score = 0.923
#   ноутбук: 2 обнаружений, средний score = 0.995
#   стул: 9 обнаружений, средний score = 0.804
#   чашка: 1 обнаружений, средний score = 0.981
#   телевизор: 2 обнаружений, средний score = 0.884
#   миска: 1 обнаружений, средний score = 0.878
#   обеденный стол: 2 обнаружений, средний score = 0.706
#   мобильный телефон: 1 обнаружений, средний score = 0.730
#   книга: 1 обнаружений, средний score = 0.638
#   мышь (компьютерная): 1 обнаружений, средний score = 0.587
#
# Image 13729:
#   человек: 4 обнаружений, средний score = 0.994
#   бутылка: 2 обнаружений, средний score = 0.976
#   пульт: 5 обнаружений, средний score = 0.827
#   обеденный стол: 1 обнаружений, средний score = 0.950
#   диван: 1 обнаружений, средний score = 0.790
#   рюкзак: 1 обнаружений, средний score = 0.685
#   чашка: 1 обнаружений, средний score = 0.544
#
# Image 13774:
#   человек: 1 обнаружений, средний score = 0.999
#
# Image 13923:
#   телевизор: 1 обнаружений, средний score = 0.996
#   ваза: 3 обнаружений, средний score = 0.832
#   диван: 1 обнаружений, средний score = 0.993
#   стул: 4 обнаружений, средний score = 0.847
#   растение в горшке: 3 обнаружений, средний score = 0.807
#   книга: 1 обнаружений, средний score = 0.796
#   обеденный стол: 1 обнаружений, средний score = 0.731
#
# Image 14007:
#   кошка: 1 обнаружений, средний score = 0.983
#   чемодан: 1 обнаружений, средний score = 0.867
#   унитаз: 1 обнаружений, средний score = 0.720
#
# Image 14038:
#   холодильник: 1 обнаружений, средний score = 0.993
#   бутылка: 2 обнаружений, средний score = 0.946
#   мобильный телефон: 1 обнаружений, средний score = 0.944
#   книга: 23 обнаружений, средний score = 0.665
#   растение в горшке: 2 обнаружений, средний score = 0.668
#   кровать: 1 обнаружений, средний score = 0.829
#   обеденный стол: 1 обнаружений, средний score = 0.773
#   миска: 2 обнаружений, средний score = 0.592
#
# Image 14226:
#   ноутбук: 1 обнаружений, средний score = 1.000
#   человек: 1 обнаружений, средний score = 0.958
#   стул: 1 обнаружений, средний score = 0.838
#   обеденный стол: 1 обнаружений, средний score = 0.538
#   диван: 1 обнаружений, средний score = 0.537
#
# Image 14380:
#   поезд: 1 обнаружений, средний score = 0.986
#
# Image 14439:
#   человек: 16 обнаружений, средний score = 0.934
#   воздушный змей: 2 обнаружений, средний score = 0.754
#   стул: 2 обнаружений, средний score = 0.789
#   рюкзак: 1 обнаружений, средний score = 0.528
#
# Image 14473:
#   поезд: 3 обнаружений, средний score = 0.791
#   человек: 6 обнаружений, средний score = 0.958
#
# Image 14831:
#   кошка: 1 обнаружений, средний score = 0.770
#
# Image 14888:
#   лошадь: 1 обнаружений, средний score = 0.661
#   бутылка: 2 обнаружений, средний score = 0.550
#
# Image 15079:
#   сэндвич: 2 обнаружений, средний score = 0.963
#   обеденный стол: 1 обнаружений, средний score = 0.723
#   нож: 1 обнаружений, средний score = 0.608
#
# Image 15254:
#   миска: 4 обнаружений, средний score = 0.973
#   морковь: 1 обнаружений, средний score = 0.877
#   ложка: 2 обнаружений, средний score = 0.680
#   обеденный стол: 1 обнаружений, средний score = 0.582
#
# Image 15272:
#   светофор: 2 обнаружений, средний score = 0.871
#
# Image 15278:
#   брокколи: 15 обнаружений, средний score = 0.735
#   пицца: 1 обнаружений, средний score = 0.608
#
# Image 15335:
#   человек: 7 обнаружений, средний score = 0.861
#   чашка: 1 обнаружений, средний score = 0.841
#
# Image 15338:
#   автобус: 2 обнаружений, средний score = 0.972
#   автомобиль: 2 обнаружений, средний score = 0.775
#   грузовик: 1 обнаружений, средний score = 0.702
#   человек: 1 обнаружений, средний score = 0.665
#
# Image 15440:
#   знак остановки: 1 обнаружений, средний score = 0.998
#   автомобиль: 2 обнаружений, средний score = 0.833
#   светофор: 1 обнаружений, средний score = 0.622
#
# Image 15497:
#   кошка: 1 обнаружений, средний score = 0.991
#   мышь (компьютерная): 1 обнаружений, средний score = 0.895
#
# Image 15517:
#   автобус: 6 обнаружений, средний score = 0.837
#   светофор: 1 обнаружений, средний score = 0.624
#   поезд: 1 обнаружений, средний score = 0.500
#
# Image 15597:
#   скейтборд: 1 обнаружений, средний score = 1.000
#   человек: 1 обнаружений, средний score = 0.997
#   птица: 1 обнаружений, средний score = 0.527
#
# Image 15660:
#   человек: 1 обнаружений, средний score = 0.999
#   воздушный змей: 5 обнаружений, средний score = 0.987
#   доска для серфинга: 2 обнаружений, средний score = 0.725
#   лодка: 1 обнаружений, средний score = 0.763
#
# Image 15746:
#   пожарный гидрант: 1 обнаружений, средний score = 0.999
#   птица: 1 обнаружений, средний score = 0.659
#
# Image 15751:
#   человек: 1 обнаружений, средний score = 0.952
#   скамейка: 2 обнаружений, средний score = 0.533
#
# Image 15956:
#   человек: 1 обнаружений, средний score = 1.000
#   лошадь: 1 обнаружений, средний score = 0.995
#   часы: 2 обнаружений, средний score = 0.768
#   стул: 1 обнаружений, средний score = 0.900
#   бутылка: 1 обнаружений, средний score = 0.593
#
# Image 16010:
#   зебра: 2 обнаружений, средний score = 0.949
#   овца: 2 обнаружений, средний score = 0.971
#   корова: 3 обнаружений, средний score = 0.675
#
# Image 16228:
#   лошадь: 1 обнаружений, средний score = 0.999
#   скамейка: 1 обнаружений, средний score = 0.992
#   человек: 20 обнаружений, средний score = 0.790
#   зонт: 4 обнаружений, средний score = 0.732
#   галстук: 1 обнаружений, средний score = 0.609
#
# Image 16249:
#   человек: 5 обнаружений, средний score = 0.970
#   скамейка: 3 обнаружений, средний score = 0.784
#   велосипед: 1 обнаружений, средний score = 0.668
#   сумка: 1 обнаружений, средний score = 0.579
#
# Image 16439:
#   ноутбук: 1 обнаружений, средний score = 0.998
#   бокал: 1 обнаружений, средний score = 0.994
#   клавиатура: 1 обнаружений, средний score = 0.502
#
# Image 16451:
#   человек: 1 обнаружений, средний score = 0.989
#   доска для серфинга: 2 обнаружений, средний score = 0.969
#   сумка: 1 обнаружений, средний score = 0.907
#   чемодан: 1 обнаружений, средний score = 0.892
#   воздушный змей: 1 обнаружений, средний score = 0.887
#   стул: 3 обнаружений, средний score = 0.844
#   зонт: 2 обнаружений, средний score = 0.568
#   рюкзак: 1 обнаружений, средний score = 0.557
#
# Image 16502:
#   овца: 1 обнаружений, средний score = 0.998
#
# Image 16598:
#   человек: 1 обнаружений, средний score = 1.000
#   мобильный телефон: 1 обнаружений, средний score = 0.996
#   галстук: 1 обнаружений, средний score = 0.673
#
# Image 16958:
#   стул: 4 обнаружений, средний score = 0.896
#   ваза: 2 обнаружений, средний score = 0.951
#   телевизор: 1 обнаружений, средний score = 0.788
#   обеденный стол: 1 обнаружений, средний score = 0.523
#
# Image 17029:
#   собака: 1 обнаружений, средний score = 0.996
#   автомобиль: 4 обнаружений, средний score = 0.924
#   фрисби: 1 обнаружений, средний score = 0.955
#
# Image 17031:
#   жираф: 1 обнаружений, средний score = 0.997
#   человек: 1 обнаружений, средний score = 0.651
#
# Image 17115:
#   зебра: 2 обнаружений, средний score = 0.999
#
# Image 17178:
#   лошадь: 4 обнаружений, средний score = 0.961
#   автомобиль: 1 обнаружений, средний score = 0.993
#
# Image 17182:
#   стул: 2 обнаружений, средний score = 0.827
#   книга: 4 обнаружений, средний score = 0.775
#   яблоко: 1 обнаружений, средний score = 0.836
#
# Image 17207:
#   автомобиль: 1 обнаружений, средний score = 0.996
#   человек: 1 обнаружений, средний score = 0.986
#   мотоцикл: 1 обнаружений, средний score = 0.982
#   грузовик: 2 обнаружений, средний score = 0.696
#   автобус: 1 обнаружений, средний score = 0.839
#
# Image 17379:
#   раковина: 2 обнаружений, средний score = 0.987
#   телевизор: 1 обнаружений, средний score = 0.988
#   человек: 2 обнаружений, средний score = 0.787
#
# Image 17436:
#   человек: 1 обнаружений, средний score = 0.999
#   скамейка: 1 обнаружений, средний score = 0.790
#   растение в горшке: 1 обнаружений, средний score = 0.659
#   спортивный мяч: 1 обнаружений, средний score = 0.537
#
# Image 17627:
#   автомобиль: 11 обнаружений, средний score = 0.910
#   человек: 3 обнаружений, средний score = 0.908
#
# Image 17714:
#   чашка: 1 обнаружений, средний score = 0.994
#   обеденный стол: 1 обнаружений, средний score = 0.967
#   вилка: 3 обнаружений, средний score = 0.767
#   нож: 1 обнаружений, средний score = 0.644
#
# Image 17899:
#   человек: 1 обнаружений, средний score = 0.998
#   чашка: 3 обнаружений, средний score = 0.910
#   обеденный стол: 1 обнаружений, средний score = 0.987
#   миска: 1 обнаружений, средний score = 0.980
#   диван: 1 обнаружений, средний score = 0.955
#   стул: 2 обнаружений, средний score = 0.931
#   пончик: 2 обнаружений, средний score = 0.553
#
# Image 17905:
#   человек: 1 обнаружений, средний score = 0.999
#   светофор: 1 обнаружений, средний score = 0.994
#
# Image 17959:
#   человек: 4 обнаружений, средний score = 0.754
#   воздушный змей: 14 обнаружений, средний score = 0.707
#
# Image 18150:
#   пицца: 1 обнаружений, средний score = 0.998
#   человек: 2 обнаружений, средний score = 0.993
#   бутылка: 1 обнаружений, средний score = 0.962
#   плюшевый мишка: 2 обнаружений, средний score = 0.612
#   диван: 1 обнаружений, средний score = 0.565
#
# Image 18193:
#   человек: 1 обнаружений, средний score = 0.970
#   стул: 2 обнаружений, средний score = 0.677
#   пицца: 1 обнаружений, средний score = 0.710
#   миска: 1 обнаружений, средний score = 0.506
#
# Image 18380:
#   человек: 18 обнаружений, средний score = 0.921
#   бокал: 4 обнаружений, средний score = 0.883
#   чашка: 12 обнаружений, средний score = 0.795
#   обеденный стол: 1 обнаружений, средний score = 0.959
#   миска: 3 обнаружений, средний score = 0.850
#   нож: 1 обнаружений, средний score = 0.805
#   стул: 1 обнаружений, средний score = 0.794
#   ваза: 1 обнаружений, средний score = 0.692
#   ложка: 2 обнаружений, средний score = 0.596
#   пицца: 1 обнаружений, средний score = 0.539
#   вилка: 1 обнаружений, средний score = 0.517
#
# Image 18491:
#   человек: 9 обнаружений, средний score = 0.956
#   бейсбольная перчатка: 2 обнаружений, средний score = 0.740
#
# Image 18519:
#   человек: 1 обнаружений, средний score = 0.999
#   скейтборд: 1 обнаружений, средний score = 0.501
#
# Image 18575:
#   обеденный стол: 1 обнаружений, средний score = 0.966
#   бутылка: 2 обнаружений, средний score = 0.903
#   сэндвич: 2 обнаружений, средний score = 0.915
#   миска: 1 обнаружений, средний score = 0.782
#   бокал: 1 обнаружений, средний score = 0.755
#   чашка: 2 обнаружений, средний score = 0.687
#   нож: 1 обнаружений, средний score = 0.698
#   апельсин: 1 обнаружений, средний score = 0.666
#
# Image 18737:
#   мотоцикл: 1 обнаружений, средний score = 0.999
#
# Image 18770:
#   человек: 1 обнаружений, средний score = 0.998
#   галстук: 2 обнаружений, средний score = 0.886
#
# Image 18833:
#   кошка: 1 обнаружений, средний score = 0.973
#   пульт: 1 обнаружений, средний score = 0.540
#
# Image 18837:
#   человек: 6 обнаружений, средний score = 0.821
#   автобус: 2 обнаружений, средний score = 0.789
#   грузовик: 1 обнаружений, средний score = 0.921
#   автомобиль: 1 обнаружений, средний score = 0.755
#
# Image 19042:
#   птица: 2 обнаружений, средний score = 0.850
#
# Image 19109:
#   мотоцикл: 14 обнаружений, средний score = 0.894
#   человек: 11 обнаружений, средний score = 0.838
#   автомобиль: 1 обнаружений, средний score = 0.965
#
# Image 19221:
#   брокколи: 2 обнаружений, средний score = 0.936
#
# Image 19402:
#   человек: 2 обнаружений, средний score = 0.734
#   чашка: 1 обнаружений, средний score = 0.610
#
# Image 19432:
#   человек: 1 обнаружений, средний score = 1.000
#   теннисная ракетка: 1 обнаружений, средний score = 1.000
#   спортивный мяч: 1 обнаружений, средний score = 0.995
#   стул: 17 обнаружений, средний score = 0.792
#
# Image 19742:
#   ваза: 1 обнаружений, средний score = 0.820
#   обеденный стол: 1 обнаружений, средний score = 0.634
#   чашка: 1 обнаружений, средний score = 0.518
#
# Image 19786:
#   человек: 2 обнаружений, средний score = 0.991
#   стул: 1 обнаружений, средний score = 0.734
#
# Image 19924:
#   человек: 1 обнаружений, средний score = 0.998
#   галстук: 1 обнаружений, средний score = 0.946
#
# Image 20059:
#   зебра: 2 обнаружений, средний score = 0.999
#
# Image 20107:
#   пожарный гидрант: 1 обнаружений, средний score = 0.990
#
# Image 20247:
#   медведь: 2 обнаружений, средний score = 0.983
#   собака: 1 обнаружений, средний score = 0.575
#
# Image 20333:
#   человек: 1 обнаружений, средний score = 1.000
#   миска: 1 обнаружений, средний score = 0.950
#   галстук: 1 обнаружений, средний score = 0.923
#
# Image 20553:
#   бутылка: 5 обнаружений, средний score = 0.838
#   плюшевый мишка: 3 обнаружений, средний score = 0.827
#   чашка: 1 обнаружений, средний score = 0.827
#   обеденный стол: 1 обнаружений, средний score = 0.631
#
# Image 20571:
#   человек: 2 обнаружений, средний score = 0.948
#   лодка: 7 обнаружений, средний score = 0.652
#   спортивный мяч: 1 обнаружений, средний score = 0.634
#   птица: 1 обнаружений, средний score = 0.595
#
# Image 20992:
#   человек: 1 обнаружений, средний score = 0.997
#   хот-дог: 1 обнаружений, средний score = 0.896
#
# Image 21167:
#   человек: 2 обнаружений, средний score = 0.997
#   бокал: 1 обнаружений, средний score = 0.988
#   галстук: 1 обнаружений, средний score = 0.890
#
# Image 21465:
#   стул: 2 обнаружений, средний score = 0.764
#   обеденный стол: 2 обнаружений, средний score = 0.827
#   ваза: 1 обнаружений, средний score = 0.829
#   человек: 2 обнаружений, средний score = 0.658
#   миска: 2 обнаружений, средний score = 0.648
#   чашка: 1 обнаружений, средний score = 0.577
#
# Image 21503:
#   клавиатура: 1 обнаружений, средний score = 0.991
#   мышь (компьютерная): 1 обнаружений, средний score = 0.898
#   обеденный стол: 1 обнаружений, средний score = 0.590
#   пицца: 1 обнаружений, средний score = 0.579
#   пульт: 1 обнаружений, средний score = 0.552
#
# Image 21604:
#   человек: 1 обнаружений, средний score = 1.000
#   галстук: 1 обнаружений, средний score = 0.970
#
# Image 21839:
#   человек: 7 обнаружений, средний score = 0.876
#   светофор: 1 обнаружений, средний score = 0.992
#   автомобиль: 1 обнаружений, средний score = 0.872
#   сумка: 2 обнаружений, средний score = 0.735
#   стул: 1 обнаружений, средний score = 0.682
#
# Image 21879:
#   человек: 3 обнаружений, средний score = 0.996
#   доска для серфинга: 6 обнаружений, средний score = 0.859
#
# Image 21903:
#   человек: 3 обнаружений, средний score = 0.890
#   слон: 1 обнаружений, средний score = 0.999
#
# Image 22192:
#   собака: 1 обнаружений, средний score = 0.994
#   книга: 1 обнаружений, средний score = 0.677
#   кровать: 2 обнаружений, средний score = 0.614
#   сумка: 1 обнаружений, средний score = 0.550
#
# Image 22371:
#   человек: 1 обнаружений, средний score = 1.000
#   ноутбук: 1 обнаружений, средний score = 0.999
#   галстук: 1 обнаружений, средний score = 0.993
#   пульт: 1 обнаружений, средний score = 0.758
#   обеденный стол: 1 обнаружений, средний score = 0.504
#
# Image 22396:
#   самолет: 1 обнаружений, средний score = 0.998
#   воздушный змей: 1 обнаружений, средний score = 0.758
#
# Image 22479:
#   скейтборд: 1 обнаружений, средний score = 1.000
#   человек: 1 обнаружений, средний score = 0.999
#   зонт: 1 обнаружений, средний score = 0.598
#
# Image 22589:
#   овца: 4 обнаружений, средний score = 0.769
#
# Image 22623:
#   морковь: 1 обнаружений, средний score = 0.577
#
# Image 22705:
#   человек: 1 обнаружений, средний score = 0.997
#   бутылка: 1 обнаружений, средний score = 0.992
#   миска: 1 обнаружений, средний score = 0.968
#   холодильник: 2 обнаружений, средний score = 0.752
#   бокал: 1 обнаружений, средний score = 0.956
#   духовка: 1 обнаружений, средний score = 0.649
#
# Image 22755:
#   автобус: 1 обнаружений, средний score = 0.912
#   автомобиль: 2 обнаружений, средний score = 0.738
#   светофор: 2 обнаружений, средний score = 0.660
#
# Image 22892:
#   собака: 1 обнаружений, средний score = 0.982
#   кошка: 1 обнаружений, средний score = 0.795
#   растение в горшке: 1 обнаружений, средний score = 0.750
#   чашка: 1 обнаружений, средний score = 0.705
#
# Image 22935:
#   человек: 2 обнаружений, средний score = 0.998
#   спортивный мяч: 1 обнаружений, средний score = 0.997
#
# Image 22969:
#   жираф: 2 обнаружений, средний score = 0.999
#
# Image 23023:
#   чемодан: 1 обнаружений, средний score = 0.986
#
# Image 23034:
#   человек: 2 обнаружений, средний score = 0.998
#   лошадь: 2 обнаружений, средний score = 0.982
#
# Image 23126:
#   лошадь: 2 обнаружений, средний score = 0.804
#   человек: 1 обнаружений, средний score = 0.998
#
# Image 23230:
#   птица: 4 обнаружений, средний score = 0.877
#
# Image 23272:
#   кошка: 1 обнаружений, средний score = 0.951
#   автомобиль: 1 обнаружений, средний score = 0.798
#   нож: 1 обнаружений, средний score = 0.533
#
# Image 23359:
#   человек: 1 обнаружений, средний score = 0.999
#   сноуборд: 1 обнаружений, средний score = 0.884
#   воздушный змей: 1 обнаружений, средний score = 0.579
#
# Image 23666:
#   унитаз: 1 обнаружений, средний score = 0.921
#   раковина: 1 обнаружений, средний score = 0.544
#
# Image 23751:
#   человек: 1 обнаружений, средний score = 0.903
#   воздушный змей: 1 обнаружений, средний score = 0.626
#
# Image 23781:
#   брокколи: 2 обнаружений, средний score = 0.936
#   морковь: 5 обнаружений, средний score = 0.865
#   миска: 2 обнаружений, средний score = 0.707
#
# Image 23899:
#   человек: 4 обнаружений, средний score = 0.868
#   мобильный телефон: 1 обнаружений, средний score = 0.679
#
# Image 23937:
#   корова: 4 обнаружений, средний score = 0.859
#   овца: 3 обнаружений, средний score = 0.663
#
# Image 24021:
#   человек: 23 обнаружений, средний score = 0.691
#   галстук: 8 обнаружений, средний score = 0.614
#
# Image 24027:
#   воздушный змей: 1 обнаружений, средний score = 0.996
#   человек: 2 обнаружений, средний score = 0.894
#   автомобиль: 3 обнаружений, средний score = 0.664
#
# Image 24144:
#   пицца: 1 обнаружений, средний score = 0.988
#
# Image 24243:
#   человек: 8 обнаружений, средний score = 0.810
#   чашка: 3 обнаружений, средний score = 0.811
#   холодильник: 1 обнаружений, средний score = 0.903
#   бутылка: 1 обнаружений, средний score = 0.593
#   автомобиль: 1 обнаружений, средний score = 0.592
#
# Image 24567:
#   человек: 1 обнаружений, средний score = 0.997
#   хот-дог: 7 обнаружений, средний score = 0.863
#   стул: 2 обнаружений, средний score = 0.699
#   обеденный стол: 1 обнаружений, средний score = 0.565
#
# Image 24610:
#   стул: 1 обнаружений, средний score = 0.998
#   ноутбук: 1 обнаружений, средний score = 0.987
#   бутылка: 1 обнаружений, средний score = 0.975
#   рюкзак: 1 обнаружений, средний score = 0.946
#   клавиатура: 1 обнаружений, средний score = 0.747
#   книга: 16 обнаружений, средний score = 0.602
#   обеденный стол: 1 обнаружений, средний score = 0.644
#   диван: 1 обнаружений, средний score = 0.590
#
# Image 24919:
#   слон: 3 обнаружений, средний score = 0.860
#
# Image 25057:
#   фрисби: 1 обнаружений, средний score = 0.999
#   человек: 2 обнаружений, средний score = 0.999
#   бутылка: 1 обнаружений, средний score = 0.680
#
# Image 25096:
#   человек: 3 обнаружений, средний score = 0.779
#   обеденный стол: 1 обнаружений, средний score = 0.953
#   нож: 1 обнаружений, средний score = 0.916
#   хот-дог: 2 обнаружений, средний score = 0.644
#
# Image 25139:
#   зебра: 3 обнаружений, средний score = 0.795
#
# Image 25181:
#   поезд: 1 обнаружений, средний score = 0.996
#   человек: 2 обнаружений, средний score = 0.950
#   скамейка: 1 обнаружений, средний score = 0.664
#
# Image 25228:
#   человек: 2 обнаружений, средний score = 0.814
#   доска для серфинга: 1 обнаружений, средний score = 0.988
#
# Image 25386:
#   человек: 2 обнаружений, средний score = 0.997
#   яблоко: 1 обнаружений, средний score = 0.643
#   обеденный стол: 1 обнаружений, средний score = 0.613
#   стул: 1 обнаружений, средний score = 0.519
#
# Image 25393:
#   человек: 3 обнаружений, средний score = 0.890
#   галстук: 2 обнаружений, средний score = 0.995
#   автомобиль: 1 обнаружений, средний score = 0.979
#
# Image 25394:
#   человек: 3 обнаружений, средний score = 0.941
#   бокал: 10 обнаружений, средний score = 0.739
#   чашка: 1 обнаружений, средний score = 0.989
#   бутылка: 18 обнаружений, средний score = 0.808
#   обеденный стол: 2 обнаружений, средний score = 0.762
#   ваза: 1 обнаружений, средний score = 0.894
#   пульт: 2 обнаружений, средний score = 0.643
#   книга: 1 обнаружений, средний score = 0.638
#
# Image 25424:
#   человек: 1 обнаружений, средний score = 0.998
#   спортивный мяч: 1 обнаружений, средний score = 0.997
#   теннисная ракетка: 1 обнаружений, средний score = 0.951
#
# Image 25560:
#   чашка: 1 обнаружений, средний score = 0.997
#   телевизор: 1 обнаружений, средний score = 0.982
#   кошка: 1 обнаружений, средний score = 0.982
#   человек: 1 обнаружений, средний score = 0.926
#   мобильный телефон: 1 обнаружений, средний score = 0.794
#   галстук: 1 обнаружений, средний score = 0.658
#
# Image 25593:
#   велосипед: 1 обнаружений, средний score = 0.982
#   светофор: 2 обнаружений, средний score = 0.635
#
# Image 25603:
#   стул: 7 обнаружений, средний score = 0.887
#   чашка: 2 обнаружений, средний score = 0.991
#   человек: 3 обнаружений, средний score = 0.951
#   обеденный стол: 1 обнаружений, средний score = 0.951
#   пицца: 1 обнаружений, средний score = 0.927
#   книга: 4 обнаружений, средний score = 0.709
#
# Image 25986:
#   чашка: 1 обнаружений, средний score = 0.996
#   ложка: 1 обнаружений, средний score = 0.989
#   миска: 3 обнаружений, средний score = 0.862
#   обеденный стол: 1 обнаружений, средний score = 0.914
#   пончик: 2 обнаружений, средний score = 0.636
#   брокколи: 5 обнаружений, средний score = 0.588
#
# Image 26204:
#   автомобиль: 9 обнаружений, средний score = 0.816
#   человек: 2 обнаружений, средний score = 0.984
#   грузовик: 2 обнаружений, средний score = 0.802
#   автобус: 1 обнаружений, средний score = 0.892
#
# Image 26465:
#   ноутбук: 1 обнаружений, средний score = 0.997
#   человек: 2 обнаружений, средний score = 0.788
#   мобильный телефон: 2 обнаружений, средний score = 0.746
#   телевизор: 1 обнаружений, средний score = 0.919
#   клавиатура: 1 обнаружений, средний score = 0.523
#
# Image 26564:
#   телевизор: 1 обнаружений, средний score = 0.999
#   мышь (компьютерная): 2 обнаружений, средний score = 0.957
#   ноутбук: 1 обнаружений, средний score = 0.998
#   клавиатура: 3 обнаружений, средний score = 0.892
#   книга: 17 обнаружений, средний score = 0.736
#   бутылка: 1 обнаружений, средний score = 0.738
#
# Image 26690:
#   человек: 13 обнаружений, средний score = 0.897
#   скейтборд: 1 обнаружений, средний score = 0.991
#
# Image 26926:
#   пожарный гидрант: 2 обнаружений, средний score = 0.824
#   автомобиль: 2 обнаружений, средний score = 0.942
#
# Image 26941:
#   чемодан: 9 обнаружений, средний score = 0.905
#   человек: 2 обнаружений, средний score = 0.836
#
# Image 27186:
#   человек: 1 обнаружений, средний score = 0.996
#   диван: 2 обнаружений, средний score = 0.881
#   пульт: 2 обнаружений, средний score = 0.714
#
# Image 27620:
#   ноутбук: 1 обнаружений, средний score = 0.997
#   клавиатура: 3 обнаружений, средний score = 0.822
#   стул: 1 обнаружений, средний score = 0.987
#   бутылка: 1 обнаружений, средний score = 0.942
#   мышь (компьютерная): 1 обнаружений, средний score = 0.931
#   кровать: 1 обнаружений, средний score = 0.726
#   ложка: 1 обнаружений, средний score = 0.725
#
# Image 27696:
#   пицца: 1 обнаружений, средний score = 0.975
#   человек: 1 обнаружений, средний score = 0.795
#   вилка: 1 обнаружений, средний score = 0.718
#
# Image 27768:
#   автобус: 1 обнаружений, средний score = 0.998
#   человек: 4 обнаружений, средний score = 0.873
#
# Image 27972:
#   человек: 1 обнаружений, средний score = 0.999
#   доска для серфинга: 1 обнаружений, средний score = 0.996
#
# Image 27982:
#   унитаз: 1 обнаружений, средний score = 0.998
#   раковина: 1 обнаружений, средний score = 0.943
#
# Image 28285:
#   часы: 1 обнаружений, средний score = 0.987
#
# Image 28449:
#   слон: 4 обнаружений, средний score = 0.960
#
# Image 28452:
#   холодильник: 1 обнаружений, средний score = 0.987
#   бутылка: 1 обнаружений, средний score = 0.987
#   миска: 1 обнаружений, средний score = 0.682
#
# Image 28809:
#   банан: 7 обнаружений, средний score = 0.798
#
# Image 28993:
#   человек: 4 обнаружений, средний score = 0.882
#   пожарный гидрант: 2 обнаружений, средний score = 0.673
#   ваза: 1 обнаружений, средний score = 0.687
#
# Image 29187:
#   лошадь: 1 обнаружений, средний score = 0.997
#   человек: 1 обнаружений, средний score = 0.933
#   сумка: 1 обнаружений, средний score = 0.876
#   скамейка: 1 обнаружений, средний score = 0.685
#
# Image 29393:
#   собака: 1 обнаружений, средний score = 0.999
#   апельсин: 1 обнаружений, средний score = 0.870
#
# Image 29397:
#   человек: 1 обнаружений, средний score = 0.995
#   скамейка: 1 обнаружений, средний score = 0.774
#
# Image 29596:
#   стул: 2 обнаружений, средний score = 0.995
#   диван: 1 обнаружений, средний score = 0.995
#   обеденный стол: 2 обнаружений, средний score = 0.737
#   ваза: 2 обнаружений, средний score = 0.895
#   книга: 3 обнаружений, средний score = 0.729
#   телевизор: 1 обнаружений, средний score = 0.808
#   растение в горшке: 1 обнаружений, средний score = 0.574
#
# Image 29640:
#   брокколи: 18 обнаружений, средний score = 0.746
#   ложка: 1 обнаружений, средний score = 0.967
#   миска: 1 обнаружений, средний score = 0.894
#   морковь: 10 обнаружений, средний score = 0.732
#
# Image 29675:
#   хот-дог: 3 обнаружений, средний score = 0.975
#   обеденный стол: 1 обнаружений, средний score = 0.595
#   книга: 1 обнаружений, средний score = 0.582
#
# Image 29984:
#   человек: 4 обнаружений, средний score = 0.991
#   стул: 2 обнаружений, средний score = 0.991
#   зонт: 1 обнаружений, средний score = 0.987
#
# Image 30213:
#   стул: 1 обнаружений, средний score = 0.995
#   миска: 1 обнаружений, средний score = 0.986
#   раковина: 1 обнаружений, средний score = 0.971
#   холодильник: 1 обнаружений, средний score = 0.940
#   бутылка: 1 обнаружений, средний score = 0.813
#   обеденный стол: 1 обнаружений, средний score = 0.774
#   духовка: 1 обнаружений, средний score = 0.773
#   книга: 1 обнаружений, средний score = 0.555
#
# Image 30494:
# ...
#   мотоцикл: 7 обнаружений, средний score = 0.860
#   человек: 9 обнаружений, средний score = 0.830
#   яблоко: 2 обнаружений, средний score = 0.636
#   сумка: 1 обнаружений, средний score = 0.616
#   велосипед: 1 обнаружений, средний score = 0.535
#
# Image 574810:
#   кошка: 1 обнаружений, средний score = 0.944
#   собака: 1 обнаружений, средний score = 0.516
#
# Image 574823:
#   человек: 5 обнаружений, средний score = 0.990
#
# Image 575081:
#   человек: 1 обнаружений, средний score = 0.997
#   телевизор: 1 обнаружений, средний score = 0.995
#   пульт: 1 обнаружений, средний score = 0.973
#   книга: 2 обнаружений, средний score = 0.818
#   растение в горшке: 1 обнаружений, средний score = 0.888
#
# Image 575187:
#   человек: 1 обнаружений, средний score = 0.986
#   жираф: 1 обнаружений, средний score = 0.857
#   книга: 1 обнаружений, средний score = 0.618
#   пульт: 1 обнаружений, средний score = 0.612
#
# Image 575205:
#   самолет: 1 обнаружений, средний score = 0.936
#   птица: 1 обнаружений, средний score = 0.782
#
# Image 575243:
#   человек: 1 обнаружений, средний score = 0.998
#   зонт: 1 обнаружений, средний score = 0.996
#   автомобиль: 4 обнаружений, средний score = 0.817
#   светофор: 1 обнаружений, средний score = 0.909
#
# Image 575357:
#   собака: 1 обнаружений, средний score = 0.953
#   фрисби: 1 обнаружений, средний score = 0.664
#
# Image 575372:
#   светофор: 4 обнаружений, средний score = 0.980
#
# Image 575500:
#   банан: 2 обнаружений, средний score = 0.737
#
# Image 575815:
#   пицца: 1 обнаружений, средний score = 0.996
#
# Image 575970:
#   ваза: 1 обнаружений, средний score = 0.995
#   стул: 3 обнаружений, средний score = 0.981
#   миска: 9 обнаружений, средний score = 0.816
#   холодильник: 1 обнаружений, средний score = 0.875
#   чашка: 5 обнаружений, средний score = 0.690
#   ложка: 3 обнаружений, средний score = 0.727
#   микроволновка: 1 обнаружений, средний score = 0.718
#   обеденный стол: 1 обнаружений, средний score = 0.549
#
# Image 576031:
#   человек: 5 обнаружений, средний score = 0.861
#   лыжи: 2 обнаружений, средний score = 0.733
#   автомобиль: 1 обнаружений, средний score = 0.724
#
# Image 576052:
#   лошадь: 1 обнаружений, средний score = 0.997
#   человек: 1 обнаружений, средний score = 0.994
#
# Image 576566:
#   человек: 1 обнаружений, средний score = 0.994
#   скейтборд: 1 обнаружений, средний score = 0.610
#
# Image 576654:
#   человек: 2 обнаружений, средний score = 0.984
#   воздушный змей: 1 обнаружений, средний score = 0.872
#   зонт: 1 обнаружений, средний score = 0.622
#
# Image 576955:
#   лошадь: 1 обнаружений, средний score = 0.997
#   человек: 4 обнаружений, средний score = 0.821
#   птица: 1 обнаружений, средний score = 0.836
#
# Image 577149:
#   зебра: 4 обнаружений, средний score = 0.982
#
# Image 577182:
#   птица: 1 обнаружений, средний score = 0.997
#   скамейка: 2 обнаружений, средний score = 0.963
#
# Image 577539:
#   миска: 1 обнаружений, средний score = 0.873
#   пончик: 1 обнаружений, средний score = 0.605
#   человек: 2 обнаружений, средний score = 0.596
#
# Image 577584:
#   миска: 1 обнаружений, средний score = 0.761
#
# Image 577735:
#   ваза: 1 обнаружений, средний score = 0.994
#   растение в горшке: 1 обнаружений, средний score = 0.893
#
# Image 577862:
#   жираф: 2 обнаружений, средний score = 0.998
#
# Image 577864:
#   человек: 3 обнаружений, средний score = 0.994
#   спортивный мяч: 1 обнаружений, средний score = 0.989
#
# Image 577932:
#   человек: 10 обнаружений, средний score = 0.876
#   автомобиль: 3 обнаружений, средний score = 0.978
#   сумка: 1 обнаружений, средний score = 0.972
#   рюкзак: 1 обнаружений, средний score = 0.874
#   велосипед: 1 обнаружений, средний score = 0.825
#   светофор: 2 обнаружений, средний score = 0.739
#   зонт: 1 обнаружений, средний score = 0.738
#
# Image 577959:
#   человек: 1 обнаружений, средний score = 0.998
#   воздушный змей: 1 обнаружений, средний score = 0.948
#
# Image 577976:
#   грузовик: 2 обнаружений, средний score = 0.890
#   автомобиль: 4 обнаружений, средний score = 0.795
#   растение в горшке: 1 обнаружений, средний score = 0.596
#
# Image 578093:
#   поезд: 1 обнаружений, средний score = 0.998
#   человек: 4 обнаружений, средний score = 0.778
#
# Image 578236:
#   птица: 1 обнаружений, средний score = 0.995
#   собака: 1 обнаружений, средний score = 0.902
#   скамейка: 1 обнаружений, средний score = 0.679
#
# Image 578489:
#   человек: 8 обнаружений, средний score = 0.924
#   пульт: 1 обнаружений, средний score = 0.991
#   диван: 1 обнаружений, средний score = 0.978
#   бутылка: 2 обнаружений, средний score = 0.756
#
# Image 578500:
#   диван: 3 обнаружений, средний score = 0.824
#   растение в горшке: 5 обнаружений, средний score = 0.742
#   стул: 6 обнаружений, средний score = 0.790
#   ваза: 4 обнаружений, средний score = 0.582
#   обеденный стол: 1 обнаружений, средний score = 0.658
#   книга: 1 обнаружений, средний score = 0.562
#
# Image 578545:
#   человек: 1 обнаружений, средний score = 0.996
#   кровать: 1 обнаружений, средний score = 0.992
#   книга: 1 обнаружений, средний score = 0.909
#   стул: 1 обнаружений, средний score = 0.804
#
# Image 578792:
#   мотоцикл: 1 обнаружений, средний score = 0.995
#   человек: 2 обнаружений, средний score = 0.692
#
# Image 578871:
#   человек: 1 обнаружений, средний score = 0.994
#   обеденный стол: 1 обнаружений, средний score = 0.989
#   ложка: 2 обнаружений, средний score = 0.966
#   миска: 4 обнаружений, средний score = 0.915
#   стул: 1 обнаружений, средний score = 0.938
#   автомобиль: 1 обнаружений, средний score = 0.863
#
# Image 578922:
#   ваза: 1 обнаружений, средний score = 0.988
#   чашка: 2 обнаружений, средний score = 0.823
#   растение в горшке: 1 обнаружений, средний score = 0.805
#   вилка: 1 обнаружений, средний score = 0.645
#   миска: 1 обнаружений, средний score = 0.532
#
# Image 578967:
#   поезд: 1 обнаружений, средний score = 0.996
#   человек: 2 обнаружений, средний score = 0.716
#
# Image 579070:
#   человек: 5 обнаружений, средний score = 0.992
#   чашка: 20 обнаружений, средний score = 0.947
#   обеденный стол: 4 обнаружений, средний score = 0.749
#   бутылка: 2 обнаружений, средний score = 0.895
#   миска: 2 обнаружений, средний score = 0.698
#   стул: 3 обнаружений, средний score = 0.764
#   бокал: 1 обнаружений, средний score = 0.798
#
# Image 579091:
#   брокколи: 6 обнаружений, средний score = 0.830
#   морковь: 4 обнаружений, средний score = 0.589
#
# Image 579158:
#   самолет: 1 обнаружений, средний score = 0.996
#   грузовик: 2 обнаружений, средний score = 0.656
#
# Image 579307:
#   человек: 2 обнаружений, средний score = 0.995
#   воздушный змей: 2 обнаружений, средний score = 0.697
#   рюкзак: 1 обнаружений, средний score = 0.636
#
# Image 579321:
#   человек: 2 обнаружений, средний score = 0.863
#   собака: 2 обнаружений, средний score = 0.786
#
# Image 579635:
#   человек: 1 обнаружений, средний score = 0.996
#   доска для серфинга: 1 обнаружений, средний score = 0.992
#   лодка: 2 обнаружений, средний score = 0.829
#
# Image 579655:
#   человек: 1 обнаружений, средний score = 0.999
#   книга: 2 обнаружений, средний score = 0.674
#   мобильный телефон: 1 обнаружений, средний score = 0.672
#   чашка: 1 обнаружений, средний score = 0.645
#
# Image 579818:
#   поезд: 3 обнаружений, средний score = 0.973
#   человек: 2 обнаружений, средний score = 0.853
#
# Image 579893:
#   знак остановки: 1 обнаружений, средний score = 0.998
#
# Image 579900:
#   пицца: 1 обнаружений, средний score = 0.991
#   брокколи: 12 обнаружений, средний score = 0.755
#   морковь: 3 обнаружений, средний score = 0.644
#
# Image 579902:
#   человек: 1 обнаружений, средний score = 0.998
#   автомобиль: 3 обнаружений, средний score = 0.779
#   мотоцикл: 1 обнаружений, средний score = 0.990
#
# Image 579970:
#   телевизор: 1 обнаружений, средний score = 0.988
#   стул: 2 обнаружений, средний score = 0.905
#   диван: 1 обнаружений, средний score = 0.779
#
# Image 580197:
#   человек: 3 обнаружений, средний score = 0.977
#   галстук: 2 обнаружений, средний score = 0.995
#
# Image 580294:
#   человек: 1 обнаружений, средний score = 0.994
#   миска: 3 обнаружений, средний score = 0.692
#   ложка: 1 обнаружений, средний score = 0.823
#   духовка: 1 обнаружений, средний score = 0.720
#
# Image 580410:
#   стул: 3 обнаружений, средний score = 0.750
#   диван: 1 обнаружений, средний score = 0.942
#   сумка: 1 обнаружений, средний score = 0.682
#   книга: 7 обнаружений, средний score = 0.599
#   ваза: 1 обнаружений, средний score = 0.559
#
# Image 580418:
#   корова: 3 обнаружений, средний score = 0.911
#   автомобиль: 3 обнаружений, средний score = 0.982
#   овца: 2 обнаружений, средний score = 0.580
#   знак остановки: 1 обнаружений, средний score = 0.526
#
# Image 580757:
#   пожарный гидрант: 1 обнаружений, средний score = 0.997
#   человек: 1 обнаружений, средний score = 0.524
#
# Image 581062:
#   человек: 1 обнаружений, средний score = 1.000
#   скейтборд: 1 обнаружений, средний score = 0.991
#
# Image 581100:
#   жираф: 3 обнаружений, средний score = 0.892
#   корова: 3 обнаружений, средний score = 0.799
#
# Image 581206:
#   человек: 2 обнаружений, средний score = 0.737
#   сэндвич: 2 обнаружений, средний score = 0.685
#   обеденный стол: 1 обнаружений, средний score = 0.779
#
# Image 581317:
#   человек: 1 обнаружений, средний score = 0.999
#   мобильный телефон: 1 обнаружений, средний score = 0.999
#
# Image 581357:
#   человек: 11 обнаружений, средний score = 0.737
#   скейтборд: 1 обнаружений, средний score = 0.998
#
# Image 581482:
#   часы: 2 обнаружений, средний score = 0.915
#
# Image 581615:
#   унитаз: 1 обнаружений, средний score = 0.996
#
# Image 581781:
#   банан: 18 обнаружений, средний score = 0.796
#   апельсин: 1 обнаружений, средний score = 0.502
#
# Общая сводная информация по всем изображениям:
#   Модель справилась с угадыванием человек: 12268 обнаружений, средний score = 0.865
#   Модель справилась с угадыванием стул: 1569 обнаружений, средний score = 0.761
#   Модель справилась с угадыванием телевизор: 304 обнаружений, средний score = 0.861
#   Модель справилась с угадыванием ваза: 317 обнаружений, средний score = 0.799
#   Модель справилась с угадыванием холодильник: 135 обнаружений, средний score = 0.837
#   Модель справилась с угадыванием растение в горшке: 380 обнаружений, средний score = 0.783
#   Модель справилась с угадыванием обеденный стол: 725 обнаружений, средний score = 0.770
#   Модель справилась с угадыванием часы: 255 обнаружений, средний score = 0.893
#   Модель справилась с угадыванием бутылка: 1096 обнаружений, средний score = 0.810
#   Модель справилась с угадыванием медведь: 72 обнаружений, средний score = 0.907
#   Модель справилась с угадыванием кровать: 182 обнаружений, средний score = 0.808
#   Модель справилась с угадыванием книга: 1141 обнаружений, средний score = 0.666
#   Модель справилась с угадыванием знак остановки: 79 обнаружений, средний score = 0.890
#   Модель справилась с угадыванием грузовик: 355 обнаружений, средний score = 0.759
#   Модель справилась с угадыванием автомобиль: 2074 обнаружений, средний score = 0.818
#   Модель справилась с угадыванием плюшевый мишка: 211 обнаружений, средний score = 0.846
#   Модель справилась с угадыванием лыжи: 212 обнаружений, средний score = 0.789
#   Модель справилась с угадыванием духовка: 139 обнаружений, средний score = 0.801
#   Модель справилась с угадыванием спортивный мяч: 250 обнаружений, средний score = 0.857
#   Модель справилась с угадыванием теннисная ракетка: 201 обнаружений, средний score = 0.907
#   Модель справилась с угадыванием бейсбольная бита: 137 обнаружений, средний score = 0.815
#   Модель справилась с угадыванием сумка: 371 обнаружений, средний score = 0.723
#   Модель справилась с угадыванием птица: 432 обнаружений, средний score = 0.790
#   Модель справилась с угадыванием лодка: 417 обнаружений, средний score = 0.783
#   Модель справилась с угадыванием рюкзак: 265 обнаружений, средний score = 0.724
#   Модель справилась с угадыванием мобильный телефон: 261 обнаружений, средний score = 0.807
#   Модель справилась с угадыванием торт: 283 обнаружений, средний score = 0.777
#   Модель справилась с угадыванием миска: 690 обнаружений, средний score = 0.778
#   Модель справилась с угадыванием пончик: 346 обнаружений, средний score = 0.808
#   Модель справилась с угадыванием доска для серфинга: 247 обнаружений, средний score = 0.861
#   Модель справилась с угадыванием ноутбук: 236 обнаружений, средний score = 0.875
#   Модель справилась с угадыванием клавиатура: 187 обнаружений, средний score = 0.821
#   Модель справилась с угадыванием мышь (компьютерная): 110 обнаружений, средний score = 0.917
#   Модель справилась с угадыванием автобус: 276 обнаружений, средний score = 0.881
#   Модель справилась с угадыванием кошка: 231 обнаружений, средний score = 0.907
#   Модель справилась с угадыванием самолет: 163 обнаружений, средний score = 0.892
#   Модель справилась с угадыванием зебра: 284 обнаружений, средний score = 0.924
#   Модель справилась с угадыванием чашка: 915 обнаружений, средний score = 0.801
#   Модель справилась с угадыванием светофор: 581 обнаружений, средний score = 0.820
#   Модель справилась с угадыванием яблоко: 206 обнаружений, средний score = 0.733
#   Модель справилась с угадыванием бейсбольная перчатка: 139 обнаружений, средний score = 0.844
#   Модель справилась с угадыванием бокал: 289 обнаружений, средний score = 0.820
#   Модель справилась с угадыванием морковь: 487 обнаружений, средний score = 0.720
#   Модель справилась с угадыванием нож: 229 обнаружений, средний score = 0.732
#   Модель справилась с угадыванием сэндвич: 172 обнаружений, средний score = 0.761
#   Модель справилась с угадыванием галстук: 216 обнаружений, средний score = 0.827
#   Модель справилась с угадыванием ложка: 223 обнаружений, средний score = 0.751
#   Модель справилась с угадыванием банан: 350 обнаружений, средний score = 0.749
#   Модель справилась с угадыванием воздушный змей: 367 обнаружений, средний score = 0.806
#   Модель справилась с угадыванием унитаз: 212 обнаружений, средний score = 0.873
#   Модель справилась с угадыванием брокколи: 369 обнаружений, средний score = 0.774
#   Модель справилась с угадыванием скейтборд: 175 обнаружений, средний score = 0.907
#   Модель справилась с угадыванием скамейка: 284 обнаружений, средний score = 0.783
#   Модель справилась с угадыванием диван: 231 обнаружений, средний score = 0.807
#   Модель справилась с угадыванием пульт: 279 обнаружений, средний score = 0.802
#   Модель справилась с угадыванием апельсин: 281 обнаружений, средний score = 0.751
#   Модель справилась с угадыванием овца: 418 обнаружений, средний score = 0.836
#   Модель справилась с угадыванием поезд: 192 обнаружений, средний score = 0.890
#   Модель справилась с угадыванием раковина: 255 обнаружений, средний score = 0.809
#   Модель справилась с угадыванием слон: 301 обнаружений, средний score = 0.902
#   Модель справилась с угадыванием фрисби: 118 обнаружений, средний score = 0.900
#   Модель справилась с угадыванием зонт: 417 обнаружений, средний score = 0.810
#   Модель справилась с угадыванием корова: 408 обнаружений, средний score = 0.844
#   Модель справилась с угадыванием лошадь: 306 обнаружений, средний score = 0.873
#   Модель справилась с угадыванием собака: 252 обнаружений, средний score = 0.870
#   Модель справилась с угадыванием велосипед: 272 обнаружений, средний score = 0.811
#   Модель справилась с угадыванием мотоцикл: 361 обнаружений, средний score = 0.848
#   Модель справилась с угадыванием микроволновка: 63 обнаружений, средний score = 0.836
#   Модель справилась с угадыванием вилка: 152 обнаружений, средний score = 0.818
#   Модель справилась с угадыванием пицца: 293 обнаружений, средний score = 0.849
#   Модель справилась с угадыванием пожарный гидрант: 99 обнаружений, средний score = 0.913
#   Модель справилась с угадыванием чемодан: 266 обнаружений, средний score = 0.794
#   Модель справилась с угадыванием жираф: 234 обнаружений, средний score = 0.951
#   Модель справилась с угадыванием хот-дог: 92 обнаружений, средний score = 0.791
#   Модель справилась с угадыванием сноуборд: 51 обнаружений, средний score = 0.849
#   Модель справилась с угадыванием паркомат: 59 обнаружений, средний score = 0.840
#   Модель справилась с угадыванием зубная щетка: 54 обнаружений, средний score = 0.770
#   Модель справилась с угадыванием фен: 11 обнаружений, средний score = 0.629
#   Модель справилась с угадыванием тостер: 6 обнаружений, средний score = 0.737
#   Модель справилась с угадыванием ножницы: 22 обнаружений, средний score = 0.831

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !nvidia-smi  # Должна появиться таблица с информацией о GPU
# Out:
# Tue Apr  1 16:07:47 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
